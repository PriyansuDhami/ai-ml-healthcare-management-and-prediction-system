# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("D://major project//datasets//disease_symptoms.csv")
severity_df = pd.read_csv("D://major project//datasets//symptom_severity.csv")

# %%
def normalize(s):
    if pd.isna(s):
        return ""
    return re.sub(r'[^a-z0-9]', '', str(s).strip().lower())

# %%
symptom_cols = [col for col in df.columns if col.startswith("Symptom")]

raw_symptoms = set()
for col in symptom_cols:
    raw_symptoms.update(df[col].dropna().unique())

clean_symptoms = set(normalize(s) for s in raw_symptoms if s != "")

print("\n===== DATA CLEANING ANALYSIS =====")
print("Raw Symptoms:", len(raw_symptoms))
print("Cleaned Symptoms:", len(clean_symptoms))
print("Duplicates Removed:", len(raw_symptoms) - len(clean_symptoms))

print("\nSample Raw vs Cleaned:")
for s in list(raw_symptoms)[:5]:
    print(f"{s} → {normalize(s)}")
# Out:
# ===== DATA CLEANING ANALYSIS =====
# Raw Symptoms: 18
# Cleaned Symptoms: 18
# Duplicates Removed: 0
#
# Sample Raw vs Cleaned:
# cough → cough
# weakness → weakness
# mild_fever → mildfever
# runny_nose → runnynose
# fatigue → fatigue

# %%
severity_dict = {
    normalize(row['Symptom']): int(row['Weight'])
    for _, row in severity_df.iterrows()
}

# %%
all_symptoms = sorted(clean_symptoms)

# %%
X = pd.DataFrame(0, index=df.index, columns=all_symptoms)

for i in range(len(df)):
    for col in symptom_cols:
        s = df.at[i, col]
        if pd.notna(s):
            s = normalize(s)
            if s in severity_dict:
                X.at[i, s] = severity_dict[s]

# %%
y = df['Disease']
le = LabelEncoder()
y_enc = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y_enc, test_size=0.2, stratify=y_enc, random_state=42
)

# %%
models = {
    "Naive Bayes": MultinomialNB(),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM": SVC(probability=True),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=200)
}

results = {}

# %%
print("\n===== MODEL COMPARISON =====\n")

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    acc  = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec  = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1   = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    
    results[name] = acc
    
    print(f"{name}")
    print(f" Accuracy : {acc:.4f}")
    print(f" Precision: {prec:.4f}")
    print(f" Recall   : {rec:.4f}")
    print(f" F1 Score : {f1:.4f}")
    print("-" * 40)
# Out:
# ===== MODEL COMPARISON =====
#
# Naive Bayes
#  Accuracy : 0.9800
#  Precision: 0.9818
#  Recall   : 0.9800
#  F1 Score : 0.9799
# ----------------------------------------
# Logistic Regression
#  Accuracy : 0.9900
#  Precision: 0.9905
#  Recall   : 0.9900
#  F1 Score : 0.9900
# ----------------------------------------
# SVM
#  Accuracy : 0.9900
#  Precision: 0.9905
#  Recall   : 0.9900
#  F1 Score : 0.9900
# ----------------------------------------
# Decision Tree
#  Accuracy : 0.9800
#  Precision: 0.9818
#  Recall   : 0.9800
#  F1 Score : 0.9802
# ----------------------------------------
# Random Forest
#  Accuracy : 0.9900
#  Precision: 0.9905
#  Recall   : 0.9900
#  F1 Score : 0.9900
# ----------------------------------------

# %%
print("\n===== MODEL COMPARISON =====\n")

for name, model in models.items():
    model.fit(X_train, y_train)
    trained_models[name] = model
    
    y_pred = model.predict(X_test)
    
    acc  = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec  = recall_score(y_test, y_pred, average='weighted', zero_division=0)
    f1   = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    
    print(f"{name}")
    print(f"  Accuracy : {acc:.4f}")
    print(f"  Precision: {prec:.4f}")
    print(f"  Recall   : {rec:.4f}")
    print(f"  F1 Score : {f1:.4f}")
    print("-" * 40)
# Out:
# ===== MODEL COMPARISON =====
#
# Naive Bayes
#   Accuracy : 0.9800
#   Precision: 0.9818
#   Recall   : 0.9800
#   F1 Score : 0.9799
# ----------------------------------------
# Logistic Regression
#   Accuracy : 0.9900
#   Precision: 0.9905
#   Recall   : 0.9900
#   F1 Score : 0.9900
# ----------------------------------------
# SVM
#   Accuracy : 0.9900
#   Precision: 0.9905
#   Recall   : 0.9900
#   F1 Score : 0.9900
# ----------------------------------------
# Decision Tree
#   Accuracy : 0.9800
#   Precision: 0.9818
#   Recall   : 0.9800
#   F1 Score : 0.9802
# ----------------------------------------
# Random Forest
#   Accuracy : 0.9900
#   Precision: 0.9905
#   Recall   : 0.9900
#   F1 Score : 0.9900
# ----------------------------------------

# %%
plt.figure()
plt.bar(results.keys(), results.values())
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.show()

# %%
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
def predict(symptoms):
    symptoms = [normalize(s) for s in symptoms]
    
    input_vector = [0]*len(all_symptoms)
    severity_score = 0
    
    print("\n===== INPUT ANALYSIS =====")
    
    for i, sym in enumerate(all_symptoms):
        if sym in symptoms:
            w = severity_dict.get(sym, 0)
            input_vector[i] = w
            severity_score += w
            print(f"{sym} → weight {w}")
    
    print(f"\nTotal Severity Score: {severity_score}")
    
    probs = nb_model.predict_proba([input_vector])[0]
    top = np.argmax(probs)
    
    print("\n===== FINAL PREDICTION =====")
    print("Disease:", le.classes_[top])
    print("Confidence:", probs[top]*100)

# %%
predict_all_models(["fever", "cough", "vomiting"])
# Out:
# ===== INPUT ANALYSIS =====
# cough → weight 3
# fever → weight 5
# vomiting → weight 6
#
# Total Severity Score: 14
#
# ===== PREDICTIONS (ALL MODELS) =====
#
# Naive Bayes:
#   Disease   → Typhoid
#   Confidence→ 100.00%
# ------------------------------
# Logistic Regression:
#   Disease   → Typhoid
#   Confidence→ 44.44%
# ------------------------------
# SVM:
#   Disease   → Typhoid
#   Confidence→ 52.62%
# ------------------------------
# Decision Tree:
#   Disease   → Tuberculosis
#   Confidence→ 100.00%
# ------------------------------
# Random Forest:
#   Disease   → Tuberculosis
#   Confidence→ 49.76%
# ------------------------------
# C:\Users\priya\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# ...

# %%
predict(["fever", "cough", "vomiting"])
# Out:
# ===== INPUT ANALYSIS =====
# cough → weight 3
# fever → weight 5
# vomiting → weight 6
#
# Total Severity Score: 14
#
# ===== FINAL PREDICTION =====
# Disease: Typhoid
# Confidence: 99.99999627391325
# C:\Users\priya\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
